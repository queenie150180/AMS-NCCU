# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plot([-2,0,2,4,6,8])

# %%
randn(20)
# Out:
# array([ 0.02354393, -0.81217933,  0.09651877,  1.10873889,  0.4749297 ,
#        -1.66840404,  0.29350427, -2.18105624,  1.33629146, -0.07791226,
#         0.08540772, -0.06228705, -0.36582144, -0.10799296,  2.00285685,
#         0.56062029, -0.35054653,  0.003055  ,  0.01759563,  1.19445395])

# %%
plot(randn(100))

# %%
y=[5,7,6,9,15,20]

# %%
plt.plot(y)

# %%
x=[5,7,1,2,14,25]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
x = np.linspace(0, 1, 100)

# %%
y = np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
x = np.linspace(-20, 20, 50)

# %%
y = x**2

# %%
plt.plot(x,y)
