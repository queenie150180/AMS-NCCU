# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 作業三 102.103年農業種植 資料分析

# %%
df3 = pd.read_csv("http://ipgod.nchc.org.tw/dataset/4f6733f1-2e0e-4ae1-b335-7bec5d4a1912/resource/ed090d7b-97e3-47d6-a8f0-211dfaa9a707/download/345000000g-at0078_fc624.csv")

# %%
df3.head()
# Out:
#    year  type category  plant_area  reward_area  yield_avg     yield
# 0   102  其他產品      蜂王漿           0            0          0    369100
# 1   102  其他產品       蜂蜜           0            0          0  12758000
# 2   103   花卉類      文心蘭         261          261      22003      5736
# 3   102   花卉類      文心蘭         249          249      21436      5334
# 4   103   花卉類       百合         303          303      19540      5913

# %%
df3[df3.type == "花卉類"]
# Out:
#     year type category  plant_area  reward_area  yield_avg  yield
# 2    103  花卉類      文心蘭         261          261      22003   5736
# 3    102  花卉類      文心蘭         249          249      21436   5334
# 4    103  花卉類       百合         303          303      19540   5913
# 5    102  花卉類       百合         290          290      20429   5919
# 6    103  花卉類      洋桔梗         121          121      24266   2940
# 7    102  花卉類      洋桔梗         114          114      25108   2870
# 8    103  花卉類      唐昌蒲         210          210      17306   3640
# 9    102  花卉類      唐昌蒲         197          197      16935   3343
# 10   103  花卉類       火鶴         189          189      22253   4214
# 11   102  花卉類       火鶴         198          198      21650   4284
# 12   103  花卉類       玫瑰         222          222      42813   9525
# 13   102  花卉類       玫瑰         228          228      41898   9543
# 14   103  花卉類       菊花         747          747      22847  17077
# ...

# %%
len(df3[df3.type == "花卉類"])
# Out:
# 14

# %%
len(df3[df3.type == "果品類"])
# Out:
# 42

# %%
df3[df3.category == "文心蘭"]
# Out:
#    year type category  plant_area  reward_area  yield_avg  yield
# 2   103  花卉類      文心蘭         261          261      22003   5736
# 3   102  花卉類      文心蘭         249          249      21436   5334

# %%
df3[df3.category == "檳榔"]
# Out:
#     year type category  plant_area  reward_area  yield_avg   yield
# 18   103  果品類       檳榔       44959        44511       2728  121435
# 19   102  果品類       檳榔       45792        45329       2737  124054

# %%
df3[df3.plant_area > 10000]
# Out:
#      year     type  category  plant_area  reward_area  yield_avg    yield
# 18    103      果品類        檳榔       44959        44511       2728   121435
# 19    102      果品類        檳榔       45792        45329       2737   124054
# 22    103      果品類        龍眼       11432        11417       8905   101668
# 23    102      果品類        龍眼       11498        11477       7927    90975
# 24    103      果品類        荔枝       11138        11079       8401    93078
# 25    102      果品類        荔枝       11388        11333       8225    93221
# 28    103      果品類        西瓜       10545        10545      20041   211330
# 29    102      果品類        西瓜       11193        10748      19788   212690
# 32    103      果品類        芒果       15068        14833      10311   152932
# 33    102      果品類        芒果       16509        16352      13159   215168
# 54    103      果品類        ?梨       10154         8950      50976   456243
# 56    103      果品類        香蕉       13999        13291      22565   299900
# ...

# %%
df3.sort_values(by="plant_area",ascending= False)
# Out:
#      year     type  category  plant_area  reward_area  yield_avg     yield
# 136   103  稻米及雜糧作物        稻米      271077       271051       5163   1399392
# 137   102  稻米及雜糧作物        稻米      270264       270165       4721   1275456
# 19    102      果品類        檳榔       45792        45329       2737    124054
# 18    103      果品類        檳榔       44959        44511       2728    121435
# 82    103      蔬菜類        竹筍       26323        26278      10549    277201
# 83    102      蔬菜類        竹筍       25881        25825      10342    267092
# 118   103  稻米及雜糧作物       落花生       21645        21644       3165     68513
# 119   102  稻米及雜糧作物       落花生       18610        18609       2515     46809
# 33    102      果品類        芒果       16509        16352      13159    215168
# 32    103      果品類        芒果       15068        14833      10311    152932
# 56    103      果品類        香蕉       13999        13291      22565    299900
# ...
